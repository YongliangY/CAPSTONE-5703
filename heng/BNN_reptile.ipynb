# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import random
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from copy import deepcopy
import numpy as np

# %%
class BayesianLinear(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features

        self.weight_mu = nn.Parameter(torch.Tensor(out_features, in_features))
        self.weight_rho = nn.Parameter(torch.Tensor(out_features, in_features))
        nn.init.xavier_normal_(self.weight_mu, gain=nn.init.calculate_gain('relu'))
        nn.init.uniform_(self.weight_rho, -4, -3)

        self.bias_mu = nn.Parameter(torch.Tensor(out_features))
        self.bias_rho = nn.Parameter(torch.Tensor(out_features))
        nn.init.zeros_(self.bias_mu)
        nn.init.uniform_(self.bias_rho, -5, -4)

    def forward(self, x, sample=True):
        if sample:
            weight_sigma = torch.log1p(torch.exp(self.weight_rho))
            weight = self.weight_mu + weight_sigma * torch.randn_like(weight_sigma)
            bias_sigma = torch.log1p(torch.exp(self.bias_rho))
            bias = self.bias_mu + bias_sigma * torch.randn_like(bias_sigma)
        else:
            weight, bias = self.weight_mu, self.bias_mu
        return F.linear(x, weight, bias)

    def kl_loss(self):
        weight_sigma = torch.log1p(torch.exp(self.weight_rho))
        kl = -0.5 * torch.sum(1 + 2 * torch.log(weight_sigma) - self.weight_mu.pow(2) - weight_sigma.pow(2))
        bias_sigma = torch.log1p(torch.exp(self.bias_rho))
        kl += -0.5 * torch.sum(1 + 2 * torch.log(bias_sigma) - self.bias_mu.pow(2) - bias_sigma.pow(2))
        return kl

# %%
class BNN(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dims, dropout_rate):
        super().__init__()
        self.blocks = nn.ModuleList()
        self.device = torch.device('cpu')
        prev_dim = input_dim

        # Improve the residual connection structure
        for h_dim in hidden_dims:
            main_path = nn.ModuleList([
                BayesianLinear(prev_dim, h_dim),
                nn.BatchNorm1d(h_dim),
                nn.ELU(),
                nn.Dropout(dropout_rate),
                BayesianLinear(h_dim, h_dim),
                nn.BatchNorm1d(h_dim)
            ])
            self.blocks.append(main_path)

            # Strengthen the jump connection structure
            if prev_dim != h_dim:
                skip_conn = nn.Sequential(
                    BayesianLinear(prev_dim, h_dim),
                    nn.BatchNorm1d(h_dim),
                    nn.ELU()
                )
            else:
                skip_conn = nn.Identity()
            self.blocks.append(skip_conn)

            prev_dim = h_dim
        self.out_layer = BayesianLinear(prev_dim, output_dim)

    def forward(self, x, sample=True):
        for i in range(0, len(self.blocks), 2):
            main_path = self.blocks[i]
            skip_conn = self.blocks[i + 1]

            residual = skip_conn(x) if isinstance(skip_conn, nn.Sequential) else skip_conn(x)

            x = main_path[0](x, sample)
            x = main_path[1](x)
            x = main_path[2](x)
            x = main_path[3](x)
            x = main_path[4](x, sample)
            x = main_path[5](x)

            assert x.shape == residual.shape, f"Dimension mismatch: {x.shape} vs {residual.shape}"
            x = x + residual
        return self.out_layer(x, sample)

    def kl_loss(self):
        total_kl = 0
        for i in range(0, len(self.blocks), 2):
            main_path = self.blocks[i]
            total_kl += main_path[0].kl_loss() + main_path[4].kl_loss()
        return total_kl + self.out_layer.kl_loss()

# %%
def load_data(train_path, test_path):
    train_df = pd.read_csv(train_path, header=None, skiprows=1)
    test_df = pd.read_csv(test_path, header=None, skiprows=1)

    X_train = train_df.iloc[:, :-1].values.astype('float32')
    y_train = train_df.iloc[:, -1].values.astype('int64') - 1
    X_test = test_df.iloc[:, :-1].values.astype('float32')
    y_test = test_df.iloc[:, -1].values.astype('int64') - 1

    print("\ndata distribution:")
    print(f"The number of training set samples: {len(X_train)} | class distribution: {np.bincount(y_train)}")
    print(f"The number of test set samples: {len(X_test)} | class distribution: {np.bincount(y_test)}")

    train_dataset = TensorDataset(torch.tensor(X_train), torch.tensor(y_train))
    return (
        DataLoader(train_dataset, batch_size=32, shuffle=True),
        torch.tensor(X_test),
        torch.tensor(y_test)
    )

# %%
def focal_loss(outputs, targets, class_weights, gamma=3):
    ce_loss = F.cross_entropy(outputs, targets, reduction='none')
    pt = torch.exp(-ce_loss)
    weights = class_weights.to(outputs.device)[targets]
    return (weights * (1 - pt) ** gamma * ce_loss).mean()

from torch.utils.data import DataLoader, TensorDataset, Subset

# %%
def train_reptile(model, train_loader, params, X_test, y_test):
    # Initializer meta optimizer and learning rate scheduler
    meta_optimizer = torch.optim.AdamW(model.parameters(), lr=params['meta_lr'], weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(meta_optimizer, T_max=params['num_epochs'])
    total_losses = []
    cls_losses = []      # Classification loss component
    kl_losses = []       # KL divergence loss component
    # Dynamic category weights (based on training set statistics)
    class_counts = np.bincount(train_loader.dataset.tensors[1].numpy())
    class_weights = 1.0 / (class_counts + 1e-6)
    class_weights = torch.tensor(class_weights / class_weights.sum(), dtype=torch.float32).to(model.device)

    # Training monitoring parameters
    best_f1, patience = 0, 0
    grad_history = []

    for epoch in range(params['num_epochs']):
        kl_weight = params['kl_weight'] * (0.5 * (1 + np.cos(np.pi * epoch / params['num_epochs'])))
        all_indices = np.arange(len(train_loader.dataset))
        np.random.shuffle(all_indices)
        '''
        task_size = len(train_loader.dataset) // 5  # Randomly divide into five tasks
        task_indices = [all_indices[i * task_size:(i + 1) * task_size] for i in range(5)]
        '''
        task_size = 64  # Each task has a fixed 64 samples
        task_indices = [np.random.choice(len(train_loader.dataset), task_size)
                        for _ in range(5)]
        task_loaders = [
            DataLoader(
                Subset(train_loader.dataset, indices),
                batch_size=32,
                shuffle=True,
                drop_last=True
            ) for indices in task_indices
        ]

        meta_optimizer.zero_grad()
        epoch_loss = 0
        epoch_cls = 0     # classification loss
        epoch_kl = 0      # KL loss
        for task_idx, task_loader in enumerate(task_loaders):
            # Create a temporary copy of the model
            temp_model = deepcopy(model).to(model.device)
            inner_optim = torch.optim.SGD(
                temp_model.parameters(),
                lr=params['inner_lr'],
                momentum=0.95,
                nesterov=True
            )

            for _ in range(params['num_inner_steps']):
                for X_batch, y_batch in task_loader:
                    X_batch, y_batch = X_batch.to(model.device), y_batch.to(model.device)

                    # forward propagation
                    outputs = temp_model(X_batch)

                    cls_loss = focal_loss(outputs, y_batch, class_weights)
                    kl_loss = temp_model.kl_loss()
                    loss = cls_loss + kl_weight * kl_loss
                    # back propagation
                    inner_optim.zero_grad()
                    loss.backward()
                    torch.nn.utils.clip_grad_norm_(temp_model.parameters(), max_norm=1.0)
                    inner_optim.step()
                    epoch_cls += cls_loss.item()
                    epoch_kl += kl_weight * kl_loss.item()
                    epoch_loss += loss.item()

            # Meta-gradient accumulation
            with torch.no_grad():
                for p_model, p_temp in zip(model.parameters(), temp_model.parameters()):
                    if p_model.grad is None:
                        p_model.grad = torch.zeros_like(p_model.data)
                    p_model.grad.add_((p_model.data - p_temp.data) * 0.5 / len(task_loaders))

            del temp_model

        meta_optimizer.step()
        scheduler.step()
        num_tasks = len(task_loaders)
        total_losses.append(epoch_loss / num_tasks)
        cls_losses.append(epoch_cls / num_tasks)
        kl_losses.append(epoch_kl / num_tasks)
        if (epoch + 1) % 2 == 0:
            with torch.no_grad():
                # Parameter distribution monitoring
                weight_sigma = torch.log1p(torch.exp(model.blocks[0][0].weight_rho))
                print(f"\n=== Epoch {epoch + 1}/{params['num_epochs']} ===")
                print(f"[Param] Weighted variance range: {weight_sigma.min():.3f}~{weight_sigma.max():.3f}")

                # Gradient dynamic monitoring
                grad_norms = [p.grad.norm().item() for p in model.parameters() if p.grad is not None]
                grad_history.append(np.mean(grad_norms))
                print(f"[Grad] mean value: {np.mean(grad_norms):.3e} | Max: {np.max(grad_norms):.3e}")

                # Loss component monitoring
                sample_outputs = model(X_test[:32].to(model.device))
                kl = model.kl_loss().item()
                cls_loss = F.cross_entropy(sample_outputs, y_test[:32].to(model.device)).item()
                print(f"[Loss] KL: {kl:.3f} | class: {cls_loss:.3f} | overall loss: {epoch_loss:.3f}")

        if (epoch + 1) % 5 == 0:
            metrics = evaluate(model, X_test.to(model.device), y_test.to(model.device))

            # Early stop logic
            if metrics['f1'] > best_f1:
                best_f1 = metrics['f1']
                torch.save(model.state_dict(), f'best_model_epoch{epoch + 1}.pth')
                patience = 0
            else:
                patience += 1
                if patience >= 10: #Originally it was 5
                    print(f"! Early stop is triggered at epoch {epoch + 1}，Best F1: {best_f1:.4f}")
                    return model, (total_losses, cls_losses, kl_losses)

            print(
                f"[Eval] F1: {metrics['f1']:.4f} | Acc: {metrics['accuracy']:.4f} | LR: {scheduler.get_last_lr()[0]:.2e}")

    return model, (total_losses, cls_losses, kl_losses)

# %%
def evaluate(model, X_test, y_test, num_samples=300):
    model.eval()
    logits = []
    with torch.no_grad():
        for _ in range(num_samples):
            outputs = model(X_test, sample=True)
            smoothed_outputs = (1 - 0.2) * outputs + 0.2 / outputs.shape[1]
            logits.append(smoothed_outputs)

    logits = torch.stack(logits).mean(0)
    temperature = nn.Parameter(torch.ones(1, device=logits.device))
    optimizer = torch.optim.LBFGS([temperature], lr=0.01, max_iter=500)

    def eval_loss():
        optimizer.zero_grad()
        loss = F.cross_entropy(logits / temperature, y_test)
        loss.backward()
        return loss

    for _ in range(100): optimizer.step(eval_loss)

    calib_probs = F.softmax(logits / temperature, dim=1)
    preds = calib_probs.argmax(dim=1).cpu().numpy()


    return {
        'accuracy': accuracy_score(y_test, preds),
        'precision': precision_score(y_test, preds, average='macro', zero_division=0),
        'recall': recall_score(y_test, preds, average='macro', zero_division=0),
        'f1': f1_score(y_test, preds, average='macro', zero_division=0),
        'confusion_matrix': confusion_matrix(y_test, preds)
    }

# %%
def parameter_search(train_loader, X_test, y_test, num_trials=30):
    param_space = {
        'meta_lr': [3e-4, 5e-4, 1e-3],
        'inner_lr': [0.05, 0.1, 0.15],
        'num_inner_steps': [7, 10, 15],
        'kl_weight': [0.001, 0.003, 0.005],
        'hidden_dims': [
            [512, 256, 128],
            [256, 128, 64, 32],
            [512, 512, 256, 128],
            [1024, 512]
        ],
        'dropout_rate': [0.2, 0.35, 0.5],
        'num_epochs': [100],
        'eval_samples': [60]
    }

    best_score = 0
    best_params = None
    results = []

    for trial in range(num_trials):
        params = {k: random.choice(v) for k, v in param_space.items()}
        params['hidden_dims'] = random.choice(param_space['hidden_dims'])

        print(f"\ntrial {trial + 1}/{num_trials}")
        print(f"Parameter Combination: { {k: v for k, v in params.items() if k != 'hidden_dims'} }")
        print(f"Network structure: {params['hidden_dims']}")

        model = BNN(21, 4, params['hidden_dims'], params['dropout_rate'])
        trained_model, trial_losses = train_reptile(model, train_loader, params, X_test, y_test)

        metrics = evaluate(trained_model, X_test, y_test, params['eval_samples'])
        results.append((params, metrics, trial_losses))

        if metrics['f1'] > best_score:
            best_score = metrics['f1']
            best_params = params
            torch.save(model.state_dict(), 'best_model.pth')

        print(f"Current F1: {metrics['f1']:.4f} | Best F1: {best_score:.4f}")

    #pd.DataFrame([{**p, **m} for p, m in results]).to_csv('search_results.csv', index=False)
    return best_params

# %%
train_loader, X_test, y_test = load_data('train_smote_pca.csv', 'test_smote_pca.csv')

# parameter search
print("\nStart parameter search...")
best_params = parameter_search(train_loader, X_test, y_test)

    # Final train
print("\nConduct the final training using the best parameters...")
final_model = BNN(
        input_dim=21,
        output_dim=4,
        hidden_dims=best_params['hidden_dims'],
        dropout_rate=best_params['dropout_rate']
    )
final_params = {
        **best_params,
        'num_epochs': 150,
        'kl_weight': best_params['kl_weight'] * 0.6
    }
final_model, (final_losses, cls_losses, kl_losses) = train_reptile(final_model, train_loader, final_params, X_test, y_test)

final_metrics = evaluate(final_model, X_test, y_test, num_samples=300)
print("\nFinal Performance:")
print(f"Accuracy: {final_metrics['accuracy']:.4f}")
print(f"F1: {final_metrics['f1']:.4f}")
print("confusion_matrix:\n", final_metrics['confusion_matrix'])
# Out:
# data distribution:
# The number of training set samples: 600 | class distribution: [150 150 150 150]
# The number of test set samples: 86 | class distribution: [37  6 38  5]
#
# Start parameter search...
#
# trial 1/30
# Parameter Combination: {'meta_lr': 0.0003, 'inner_lr': 0.1, 'num_inner_steps': 15, 'kl_weight': 0.001, 'dropout_rate': 0.2, 'num_epochs': 100, 'eval_samples': 60}
# Network structure: [256, 128, 64, 32]
#
# === Epoch 2/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 2.578e-01 | Max: 3.161e+00
# [Loss] KL: 413412.750 | class: 3.466 | overall loss: 61854.646
#
# === Epoch 4/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 2.546e-01 | Max: 3.179e+00
# [Loss] KL: 413329.594 | class: 1.896 | overall loss: 61716.341
# [Eval] F1: 0.1488 | Acc: 0.4186 | LR: 2.98e-04
#
# === Epoch 6/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.530e-01 | Max: 9.517e-01
# [Loss] KL: 413249.906 | class: 14.499 | overall loss: 61625.209
#
# === Epoch 8/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.457e-01 | Max: 8.286e-01
# [Loss] KL: 413180.625 | class: 7.527 | overall loss: 61251.901
#
# === Epoch 10/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.537e-01 | Max: 1.227e+00
# [Loss] KL: 413117.031 | class: 8.141 | overall loss: 60718.765
# [Eval] F1: 0.3609 | Acc: 0.5349 | LR: 2.93e-04
#
# === Epoch 12/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.413e-01 | Max: 1.048e+00
# [Loss] KL: 413056.875 | class: 7.967 | overall loss: 60115.644
#
# === Epoch 14/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.353e-01 | Max: 9.755e-01
# [Loss] KL: 412999.750 | class: 4.062 | overall loss: 59394.848
# [Eval] F1: 0.5148 | Acc: 0.7326 | LR: 2.84e-04
#
# === Epoch 16/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.469e-01 | Max: 1.192e+00
# [Loss] KL: 412944.031 | class: 4.333 | overall loss: 58532.352
#
# === Epoch 18/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.409e-01 | Max: 1.128e+00
# [Loss] KL: 412889.594 | class: 4.376 | overall loss: 57599.238
#
# === Epoch 20/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.373e-01 | Max: 1.121e+00
# [Loss] KL: 412836.281 | class: 5.422 | overall loss: 56545.516
# [Eval] F1: 0.5767 | Acc: 0.8023 | LR: 2.71e-04
#
# === Epoch 22/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.343e-01 | Max: 1.187e+00
# [Loss] KL: 412783.438 | class: 3.386 | overall loss: 55391.150
#
# === Epoch 24/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.334e-01 | Max: 1.202e+00
# [Loss] KL: 412730.688 | class: 4.488 | overall loss: 54142.080
# [Eval] F1: 0.6256 | Acc: 0.8023 | LR: 2.56e-04
#
# === Epoch 26/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.346e-01 | Max: 1.238e+00
# [Loss] KL: 412678.500 | class: 4.766 | overall loss: 52806.159
#
# === Epoch 28/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.344e-01 | Max: 1.212e+00
# [Loss] KL: 412627.438 | class: 4.148 | overall loss: 51378.348
#
# === Epoch 30/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.363e-01 | Max: 1.301e+00
# [Loss] KL: 412577.156 | class: 3.462 | overall loss: 49872.324
# [Eval] F1: 0.6693 | Acc: 0.8140 | LR: 2.38e-04
#
# === Epoch 32/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.293e-01 | Max: 1.121e+00
# [Loss] KL: 412528.000 | class: 2.628 | overall loss: 48303.709
#
# === Epoch 34/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.325e-01 | Max: 1.352e+00
# [Loss] KL: 412478.812 | class: 3.878 | overall loss: 46642.464
# [Eval] F1: 0.6693 | Acc: 0.8140 | LR: 2.18e-04
#
# === Epoch 36/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.318e-01 | Max: 1.262e+00
# [Loss] KL: 412430.594 | class: 3.408 | overall loss: 44941.163
#
# === Epoch 38/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.270e-01 | Max: 1.185e+00
# [Loss] KL: 412383.219 | class: 2.578 | overall loss: 43184.212
#
# === Epoch 40/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.292e-01 | Max: 1.274e+00
# [Loss] KL: 412337.844 | class: 2.668 | overall loss: 41370.993
# [Eval] F1: 0.6926 | Acc: 0.8140 | LR: 1.96e-04
#
# === Epoch 42/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.228e-01 | Max: 1.122e+00
# [Loss] KL: 412294.156 | class: 3.654 | overall loss: 39527.483
#
# === Epoch 44/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.248e-01 | Max: 1.173e+00
# [Loss] KL: 412252.812 | class: 3.374 | overall loss: 37638.195
# [Eval] F1: 0.6926 | Acc: 0.8140 | LR: 1.73e-04
#
# === Epoch 46/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.152e-01 | Max: 1.026e+00
# [Loss] KL: 412213.844 | class: 3.010 | overall loss: 35735.691
#
# === Epoch 48/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.222e-01 | Max: 1.164e+00
# [Loss] KL: 412177.281 | class: 3.095 | overall loss: 33798.719
#
# === Epoch 50/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.113e-01 | Max: 9.602e-01
# [Loss] KL: 412143.500 | class: 3.620 | overall loss: 31870.153
# [Eval] F1: 0.6992 | Acc: 0.8256 | LR: 1.50e-04
#
# === Epoch 52/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.168e-01 | Max: 1.082e+00
# [Loss] KL: 412112.156 | class: 3.661 | overall loss: 29920.395
#
# === Epoch 54/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.056e-01 | Max: 8.470e-01
# [Loss] KL: 412083.500 | class: 4.742 | overall loss: 27994.227
# [Eval] F1: 0.6926 | Acc: 0.8140 | LR: 1.27e-04
#
# === Epoch 56/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.068e-01 | Max: 8.873e-01
# [Loss] KL: 412057.000 | class: 3.094 | overall loss: 26063.370
#
# === Epoch 58/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.018e-01 | Max: 8.463e-01
# [Loss] KL: 412033.062 | class: 3.114 | overall loss: 24156.218
#
# === Epoch 60/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.010e-01 | Max: 8.250e-01
# [Loss] KL: 412011.625 | class: 3.568 | overall loss: 22274.851
# [Eval] F1: 0.6803 | Acc: 0.8023 | LR: 1.04e-04
#
# === Epoch 62/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.308e-02 | Max: 7.203e-01
# [Loss] KL: 411992.375 | class: 2.819 | overall loss: 20431.783
#
# === Epoch 64/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.927e-02 | Max: 7.549e-01
# [Loss] KL: 411975.438 | class: 3.072 | overall loss: 18623.496
# [Eval] F1: 0.6869 | Acc: 0.8140 | LR: 8.19e-05
#
# === Epoch 66/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.993e-02 | Max: 6.645e-01
# [Loss] KL: 411960.719 | class: 3.534 | overall loss: 16873.267
#
# === Epoch 68/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.660e-02 | Max: 5.327e-01
# [Loss] KL: 411947.969 | class: 3.918 | overall loss: 15175.413
#
# === Epoch 70/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.611e-02 | Max: 4.688e-01
# [Loss] KL: 411937.250 | class: 3.678 | overall loss: 13538.409
# [Eval] F1: 0.6869 | Acc: 0.8140 | LR: 6.18e-05
#
# === Epoch 72/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.321e-02 | Max: 4.411e-01
# [Loss] KL: 411928.375 | class: 2.751 | overall loss: 11973.456
#
# === Epoch 74/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.450e-02 | Max: 4.412e-01
# [Loss] KL: 411921.156 | class: 2.695 | overall loss: 10468.345
# [Eval] F1: 0.6869 | Acc: 0.8140 | LR: 4.39e-05
#
# === Epoch 76/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.782e-02 | Max: 4.215e-01
# [Loss] KL: 411915.312 | class: 4.110 | overall loss: 9060.491
#
# === Epoch 78/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.016e-02 | Max: 3.980e-01
# [Loss] KL: 411910.812 | class: 3.594 | overall loss: 7731.978
#
# === Epoch 80/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.907e-02 | Max: 3.950e-01
# [Loss] KL: 411907.219 | class: 3.173 | overall loss: 6496.578
# [Eval] F1: 0.6869 | Acc: 0.8140 | LR: 2.86e-05
#
# === Epoch 82/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.354e-02 | Max: 3.683e-01
# [Loss] KL: 411904.562 | class: 2.503 | overall loss: 5351.125
#
# === Epoch 84/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.791e-02 | Max: 4.279e-01
# [Loss] KL: 411902.625 | class: 2.644 | overall loss: 4317.586
# [Eval] F1: 0.6869 | Acc: 0.8140 | LR: 1.63e-05
#
# === Epoch 86/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.588e-02 | Max: 4.153e-01
# [Loss] KL: 411901.281 | class: 3.751 | overall loss: 3380.121
#
# === Epoch 88/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.038e-02 | Max: 3.766e-01
# [Loss] KL: 411900.375 | class: 2.960 | overall loss: 2553.655
#
# === Epoch 90/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.197e-02 | Max: 4.042e-01
# [Loss] KL: 411899.750 | class: 2.922 | overall loss: 1843.787
# [Eval] F1: 0.6869 | Acc: 0.8140 | LR: 7.34e-06
#
# === Epoch 92/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.279e-02 | Max: 4.212e-01
# [Loss] KL: 411899.375 | class: 2.421 | overall loss: 1241.919
#
# === Epoch 94/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.975e-02 | Max: 3.935e-01
# [Loss] KL: 411899.250 | class: 3.517 | overall loss: 756.125
# [Eval] F1: 0.6869 | Acc: 0.8140 | LR: 1.85e-06
#
# === Epoch 96/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.827e-02 | Max: 4.050e-01
# [Loss] KL: 411899.094 | class: 3.636 | overall loss: 393.184
#
# === Epoch 98/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.624e-02 | Max: 3.852e-01
# [Loss] KL: 411899.062 | class: 2.345 | overall loss: 152.713
#
# === Epoch 100/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.776e-02 | Max: 3.789e-01
# [Loss] KL: 411899.062 | class: 3.311 | overall loss: 28.670
# ! Early stop is triggered at epoch 100，Best F1: 0.6992
# Current F1: 0.6869 | Best F1: 0.6869
#
# trial 2/30
# Parameter Combination: {'meta_lr': 0.0003, 'inner_lr': 0.15, 'num_inner_steps': 7, 'kl_weight': 0.001, 'dropout_rate': 0.5, 'num_epochs': 100, 'eval_samples': 60}
# Network structure: [512, 512, 256, 128]
#
# === Epoch 2/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.649e-01 | Max: 1.315e+00
# [Loss] KL: 3160526.750 | class: 1.994 | overall loss: 221106.071
#
# === Epoch 4/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.652e-01 | Max: 1.421e+00
# [Loss] KL: 3159899.750 | class: 1.670 | overall loss: 220607.221
# [Eval] F1: 0.5492 | Acc: 0.7791 | LR: 2.98e-04
#
# === Epoch 6/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.096e-01 | Max: 6.839e-01
# [Loss] KL: 3159286.750 | class: 4.887 | overall loss: 219767.405
#
# === Epoch 8/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.034e-01 | Max: 6.576e-01
# [Loss] KL: 3158716.500 | class: 1.934 | overall loss: 218426.422
#
# === Epoch 10/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.087e-01 | Max: 7.618e-01
# [Loss] KL: 3158171.250 | class: 3.350 | overall loss: 216647.682
# [Eval] F1: 0.5200 | Acc: 0.7674 | LR: 2.93e-04
#
# === Epoch 12/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.060e-01 | Max: 7.354e-01
# [Loss] KL: 3157641.250 | class: 3.037 | overall loss: 214464.778
#
# === Epoch 14/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.180e-01 | Max: 9.243e-01
# [Loss] KL: 3157109.000 | class: 2.164 | overall loss: 211853.966
# [Eval] F1: 0.6156 | Acc: 0.7791 | LR: 2.84e-04
#
# === Epoch 16/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.247e-01 | Max: 1.013e+00
# [Loss] KL: 3156574.250 | class: 2.259 | overall loss: 208849.280
#
# === Epoch 18/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.352e-01 | Max: 1.190e+00
# [Loss] KL: 3156031.000 | class: 2.513 | overall loss: 205450.971
#
# === Epoch 20/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.358e-01 | Max: 1.174e+00
# [Loss] KL: 3155480.500 | class: 3.377 | overall loss: 201707.072
# [Eval] F1: 0.6579 | Acc: 0.8023 | LR: 2.71e-04
#
# === Epoch 22/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.201e-01 | Max: 9.707e-01
# [Loss] KL: 3154932.000 | class: 3.058 | overall loss: 197609.400
#
# === Epoch 24/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.322e-01 | Max: 1.152e+00
# [Loss] KL: 3154390.750 | class: 1.887 | overall loss: 193142.171
# [Eval] F1: 0.6625 | Acc: 0.8023 | LR: 2.56e-04
#
# === Epoch 26/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.671e-01 | Max: 1.674e+00
# [Loss] KL: 3153846.500 | class: 2.583 | overall loss: 188308.804
#
# === Epoch 28/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.356e-01 | Max: 1.207e+00
# [Loss] KL: 3153304.000 | class: 2.996 | overall loss: 183272.229
#
# === Epoch 30/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.436e-01 | Max: 1.338e+00
# [Loss] KL: 3152771.000 | class: 2.532 | overall loss: 177889.545
# [Eval] F1: 0.6625 | Acc: 0.8023 | LR: 2.38e-04
#
# === Epoch 32/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.494e-01 | Max: 1.423e+00
# [Loss] KL: 3152246.500 | class: 2.528 | overall loss: 172249.986
#
# === Epoch 34/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.428e-01 | Max: 1.334e+00
# [Loss] KL: 3151732.000 | class: 1.922 | overall loss: 166381.921
# [Eval] F1: 0.6530 | Acc: 0.7907 | LR: 2.18e-04
#
# === Epoch 36/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.489e-01 | Max: 1.396e+00
# [Loss] KL: 3151230.000 | class: 1.458 | overall loss: 160278.630
#
# === Epoch 38/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.374e-01 | Max: 1.283e+00
# [Loss] KL: 3150751.500 | class: 1.696 | overall loss: 153996.536
#
# === Epoch 40/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.496e-01 | Max: 1.457e+00
# [Loss] KL: 3150296.000 | class: 2.139 | overall loss: 147524.170
# [Eval] F1: 0.6727 | Acc: 0.8140 | LR: 1.96e-04
#
# === Epoch 42/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.344e-01 | Max: 1.229e+00
# [Loss] KL: 3149864.500 | class: 2.205 | overall loss: 140935.045
#
# === Epoch 44/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.446e-01 | Max: 1.392e+00
# [Loss] KL: 3149454.750 | class: 1.868 | overall loss: 134201.410
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 1.73e-04
#
# === Epoch 46/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.361e-01 | Max: 1.247e+00
# [Loss] KL: 3149064.250 | class: 2.362 | overall loss: 127395.211
#
# === Epoch 48/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.165e-01 | Max: 9.465e-01
# [Loss] KL: 3148700.000 | class: 2.156 | overall loss: 120536.240
#
# === Epoch 50/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.221e-01 | Max: 1.098e+00
# [Loss] KL: 3148362.500 | class: 1.270 | overall loss: 113604.498
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 1.50e-04
#
# === Epoch 52/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.143e-01 | Max: 9.575e-01
# [Loss] KL: 3148052.000 | class: 1.650 | overall loss: 106681.785
#
# === Epoch 54/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.061e-01 | Max: 8.554e-01
# [Loss] KL: 3147763.500 | class: 1.817 | overall loss: 99774.051
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 1.27e-04
#
# === Epoch 56/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.125e-01 | Max: 9.922e-01
# [Loss] KL: 3147502.500 | class: 1.763 | overall loss: 92893.448
#
# === Epoch 58/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.033e-01 | Max: 8.314e-01
# [Loss] KL: 3147267.250 | class: 1.474 | overall loss: 86099.864
#
# === Epoch 60/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.797e-02 | Max: 7.058e-01
# [Loss] KL: 3147059.250 | class: 2.124 | overall loss: 79399.616
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 1.04e-04
#
# === Epoch 62/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.467e-02 | Max: 7.138e-01
# [Loss] KL: 3146875.250 | class: 1.531 | overall loss: 72813.655
#
# === Epoch 64/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.663e-02 | Max: 5.925e-01
# [Loss] KL: 3146715.000 | class: 1.896 | overall loss: 66384.957
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 8.19e-05
#
# === Epoch 66/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.153e-02 | Max: 4.907e-01
# [Loss] KL: 3146578.250 | class: 1.191 | overall loss: 60127.087
#
# === Epoch 68/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.071e-02 | Max: 6.118e-01
# [Loss] KL: 3146461.500 | class: 1.664 | overall loss: 54057.662
#
# === Epoch 70/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.899e-02 | Max: 5.913e-01
# [Loss] KL: 3146362.500 | class: 1.047 | overall loss: 48216.066
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 6.18e-05
#
# === Epoch 72/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.295e-02 | Max: 4.226e-01
# [Loss] KL: 3146279.750 | class: 0.969 | overall loss: 42623.274
#
# === Epoch 74/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.080e-02 | Max: 3.996e-01
# [Loss] KL: 3146212.000 | class: 1.068 | overall loss: 37294.050
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 4.39e-05
#
# === Epoch 76/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.314e-02 | Max: 2.959e-01
# [Loss] KL: 3146157.500 | class: 1.476 | overall loss: 32254.374
#
# === Epoch 78/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.128e-02 | Max: 3.361e-01
# [Loss] KL: 3146113.750 | class: 1.559 | overall loss: 27517.336
#
# === Epoch 80/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.956e-02 | Max: 2.690e-01
# [Loss] KL: 3146080.750 | class: 1.543 | overall loss: 23107.822
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 2.86e-05
#
# === Epoch 82/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.667e-02 | Max: 2.578e-01
# [Loss] KL: 3146055.000 | class: 0.979 | overall loss: 19043.005
#
# === Epoch 84/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.820e-02 | Max: 2.226e-01
# [Loss] KL: 3146036.750 | class: 1.040 | overall loss: 15336.104
# [Eval] F1: 0.6624 | Acc: 0.8023 | LR: 1.63e-05
#
# === Epoch 86/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.893e-02 | Max: 2.474e-01
# [Loss] KL: 3146023.500 | class: 1.700 | overall loss: 12005.893
#
# === Epoch 88/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.056e-02 | Max: 2.086e-01
# [Loss] KL: 3146014.750 | class: 2.144 | overall loss: 9058.189
#
# === Epoch 90/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.745e-02 | Max: 2.707e-01
# [Loss] KL: 3146008.750 | class: 0.945 | overall loss: 6515.836
# ! Early stop is triggered at epoch 90，Best F1: 0.6727
# Current F1: 0.6624 | Best F1: 0.6869
#
# trial 3/30
# Parameter Combination: {'meta_lr': 0.0005, 'inner_lr': 0.1, 'num_inner_steps': 15, 'kl_weight': 0.001, 'dropout_rate': 0.2, 'num_epochs': 100, 'eval_samples': 60}
# Network structure: [256, 128, 64, 32]
#
# === Epoch 2/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 2.579e-01 | Max: 3.308e+00
# [Loss] KL: 413420.062 | class: 2.032 | overall loss: 61845.421
#
# === Epoch 4/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 2.551e-01 | Max: 3.362e+00
# [Loss] KL: 413281.094 | class: 1.675 | overall loss: 61694.299
# [Eval] F1: 0.1625 | Acc: 0.1977 | LR: 4.97e-04
#
# === Epoch 6/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.598e-01 | Max: 1.405e+00
# [Loss] KL: 413146.250 | class: 8.245 | overall loss: 61558.143
#
# === Epoch 8/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.544e-01 | Max: 1.383e+00
# [Loss] KL: 413025.062 | class: 6.077 | overall loss: 61171.608
#
# === Epoch 10/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.610e-01 | Max: 1.639e+00
# [Loss] KL: 412911.156 | class: 4.573 | overall loss: 60650.985
# [Eval] F1: 0.4821 | Acc: 0.4884 | LR: 4.88e-04
#
# === Epoch 12/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.487e-01 | Max: 1.480e+00
# [Loss] KL: 412801.406 | class: 5.216 | overall loss: 60037.763
#
# === Epoch 14/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.497e-01 | Max: 1.512e+00
# [Loss] KL: 412695.062 | class: 3.583 | overall loss: 59305.714
# [Eval] F1: 0.6158 | Acc: 0.7209 | LR: 4.73e-04
#
# === Epoch 16/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.622e-01 | Max: 1.887e+00
# [Loss] KL: 412589.594 | class: 2.745 | overall loss: 58432.426
#
# === Epoch 18/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.593e-01 | Max: 1.872e+00
# [Loss] KL: 412483.781 | class: 2.500 | overall loss: 57483.177
#
# === Epoch 20/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.509e-01 | Max: 1.688e+00
# [Loss] KL: 412378.219 | class: 2.702 | overall loss: 56440.832
# [Eval] F1: 0.6503 | Acc: 0.7442 | LR: 4.52e-04
#
# === Epoch 22/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.614e-01 | Max: 1.989e+00
# [Loss] KL: 412272.094 | class: 3.034 | overall loss: 55261.911
#
# === Epoch 24/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.639e-01 | Max: 2.094e+00
# [Loss] KL: 412165.812 | class: 2.842 | overall loss: 54004.717
# [Eval] F1: 0.6475 | Acc: 0.7674 | LR: 4.27e-04
#
# === Epoch 26/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.557e-01 | Max: 1.803e+00
# [Loss] KL: 412061.219 | class: 1.906 | overall loss: 52686.292
#
# === Epoch 28/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.619e-01 | Max: 2.072e+00
# [Loss] KL: 411958.156 | class: 2.658 | overall loss: 51238.965
#
# === Epoch 30/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.554e-01 | Max: 1.892e+00
# [Loss] KL: 411856.125 | class: 3.127 | overall loss: 49747.468
# [Eval] F1: 0.6647 | Acc: 0.7907 | LR: 3.97e-04
#
# === Epoch 32/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.561e-01 | Max: 1.947e+00
# [Loss] KL: 411756.562 | class: 1.677 | overall loss: 48165.275
#
# === Epoch 34/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.474e-01 | Max: 1.658e+00
# [Loss] KL: 411660.688 | class: 2.100 | overall loss: 46536.854
# [Eval] F1: 0.6741 | Acc: 0.8023 | LR: 3.63e-04
#
# === Epoch 36/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.464e-01 | Max: 1.758e+00
# [Loss] KL: 411568.781 | class: 2.817 | overall loss: 44819.611
#
# === Epoch 38/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.476e-01 | Max: 1.786e+00
# [Loss] KL: 411480.312 | class: 2.653 | overall loss: 43056.357
#
# === Epoch 40/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.409e-01 | Max: 1.699e+00
# [Loss] KL: 411395.156 | class: 2.059 | overall loss: 41250.762
# [Eval] F1: 0.6741 | Acc: 0.8023 | LR: 3.27e-04
#
# === Epoch 42/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.472e-01 | Max: 1.869e+00
# [Loss] KL: 411313.219 | class: 2.288 | overall loss: 39395.444
#
# === Epoch 44/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.427e-01 | Max: 1.788e+00
# [Loss] KL: 411235.000 | class: 2.010 | overall loss: 37515.012
# [Eval] F1: 0.6846 | Acc: 0.8140 | LR: 2.89e-04
#
# === Epoch 46/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.425e-01 | Max: 1.804e+00
# [Loss] KL: 411161.156 | class: 2.070 | overall loss: 35607.572
#
# === Epoch 48/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.298e-01 | Max: 1.559e+00
# [Loss] KL: 411092.188 | class: 2.042 | overall loss: 33692.507
#
# === Epoch 50/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.279e-01 | Max: 1.515e+00
# [Loss] KL: 411028.312 | class: 2.467 | overall loss: 31759.256
# [Eval] F1: 0.6846 | Acc: 0.8140 | LR: 2.50e-04
#
# === Epoch 52/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.232e-01 | Max: 1.367e+00
# [Loss] KL: 410969.781 | class: 1.727 | overall loss: 29825.180
#
# === Epoch 54/100 ===
# [Param] Weighted variance range: 0.019~0.049
# [Grad] mean value: 1.171e-01 | Max: 1.424e+00
# [Loss] KL: 410916.562 | class: 1.868 | overall loss: 27887.710
# [Eval] F1: 0.6846 | Acc: 0.8140 | LR: 2.11e-04
#
# === Epoch 56/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 1.124e-01 | Max: 1.247e+00
# [Loss] KL: 410868.188 | class: 2.093 | overall loss: 25973.164
#
# === Epoch 58/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 1.078e-01 | Max: 1.284e+00
# [Loss] KL: 410824.500 | class: 1.507 | overall loss: 24066.950
#
# === Epoch 60/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 1.036e-01 | Max: 1.180e+00
# [Loss] KL: 410785.344 | class: 2.476 | overall loss: 22193.348
# [Eval] F1: 0.6846 | Acc: 0.8140 | LR: 1.73e-04
#
# === Epoch 62/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 9.900e-02 | Max: 1.077e+00
# [Loss] KL: 410750.188 | class: 2.012 | overall loss: 20356.855
#
# === Epoch 64/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 9.430e-02 | Max: 1.038e+00
# [Loss] KL: 410719.438 | class: 1.521 | overall loss: 18555.490
# [Eval] F1: 0.6846 | Acc: 0.8140 | LR: 1.37e-04
#
# === Epoch 66/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 8.905e-02 | Max: 7.854e-01
# [Loss] KL: 410692.906 | class: 1.824 | overall loss: 16814.314
#
# === Epoch 68/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 8.595e-02 | Max: 7.681e-01
# [Loss] KL: 410670.531 | class: 2.000 | overall loss: 15118.157
#
# === Epoch 70/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 8.166e-02 | Max: 6.538e-01
# [Loss] KL: 410651.656 | class: 1.754 | overall loss: 13486.703
# [Eval] F1: 0.7003 | Acc: 0.8256 | LR: 1.03e-04
#
# === Epoch 72/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 8.320e-02 | Max: 5.976e-01
# [Loss] KL: 410635.969 | class: 1.804 | overall loss: 11923.679
#
# === Epoch 74/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 7.342e-02 | Max: 5.271e-01
# [Loss] KL: 410623.156 | class: 1.180 | overall loss: 10432.431
# [Eval] F1: 0.7003 | Acc: 0.8256 | LR: 7.32e-05
#
# === Epoch 76/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 6.258e-02 | Max: 4.820e-01
# [Loss] KL: 410612.781 | class: 1.636 | overall loss: 9020.967
#
# === Epoch 78/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 6.317e-02 | Max: 4.341e-01
# [Loss] KL: 410604.562 | class: 1.634 | overall loss: 7696.335
#
# === Epoch 80/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 6.422e-02 | Max: 3.346e-01
# [Loss] KL: 410598.250 | class: 1.632 | overall loss: 6468.538
# [Eval] F1: 0.7003 | Acc: 0.8256 | LR: 4.77e-05
#
# === Epoch 82/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.617e-02 | Max: 2.933e-01
# [Loss] KL: 410593.531 | class: 1.543 | overall loss: 5328.758
#
# === Epoch 84/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.599e-02 | Max: 3.153e-01
# [Loss] KL: 410590.094 | class: 1.046 | overall loss: 4293.366
# [Eval] F1: 0.7003 | Acc: 0.8256 | LR: 2.72e-05
#
# === Epoch 86/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.204e-02 | Max: 3.078e-01
# [Loss] KL: 410587.594 | class: 2.063 | overall loss: 3361.043
#
# === Epoch 88/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.593e-02 | Max: 3.609e-01
# [Loss] KL: 410585.969 | class: 1.637 | overall loss: 2538.958
#
# === Epoch 90/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.582e-02 | Max: 2.792e-01
# [Loss] KL: 410584.938 | class: 1.659 | overall loss: 1824.912
# [Eval] F1: 0.7071 | Acc: 0.8372 | LR: 1.22e-05
#
# === Epoch 92/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.806e-02 | Max: 3.082e-01
# [Loss] KL: 410584.312 | class: 1.541 | overall loss: 1228.883
#
# === Epoch 94/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.081e-02 | Max: 2.818e-01
# [Loss] KL: 410583.969 | class: 1.338 | overall loss: 745.787
# [Eval] F1: 0.7003 | Acc: 0.8256 | LR: 3.08e-06
#
# === Epoch 96/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.675e-02 | Max: 3.102e-01
# [Loss] KL: 410583.844 | class: 1.689 | overall loss: 385.961
#
# === Epoch 98/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.045e-02 | Max: 2.792e-01
# [Loss] KL: 410583.719 | class: 1.528 | overall loss: 141.081
#
# === Epoch 100/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.433e-02 | Max: 2.965e-01
# [Loss] KL: 410583.719 | class: 1.677 | overall loss: 20.954
# [Eval] F1: 0.7003 | Acc: 0.8256 | LR: 0.00e+00
# Current F1: 0.7003 | Best F1: 0.7003
#
# trial 4/30
# Parameter Combination: {'meta_lr': 0.001, 'inner_lr': 0.1, 'num_inner_steps': 15, 'kl_weight': 0.005, 'dropout_rate': 0.5, 'num_epochs': 100, 'eval_samples': 60}
# Network structure: [256, 128, 64, 32]
#
# === Epoch 2/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.238e-01 | Max: 8.423e+00
# [Loss] KL: 413245.875 | class: 2.819 | overall loss: 307697.824
#
# === Epoch 4/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.306e-01 | Max: 8.659e+00
# [Loss] KL: 412959.531 | class: 2.678 | overall loss: 306760.480
# [Eval] F1: 0.4392 | Acc: 0.5000 | LR: 9.94e-04
#
# === Epoch 6/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.044e-01 | Max: 6.389e+00
# [Loss] KL: 412676.406 | class: 5.953 | overall loss: 306019.290
#
# === Epoch 8/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.014e-01 | Max: 6.363e+00
# [Loss] KL: 412404.219 | class: 3.504 | overall loss: 304008.228
#
# === Epoch 10/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.378e-01 | Max: 7.219e+00
# [Loss] KL: 412135.406 | class: 4.227 | overall loss: 301099.865
# [Eval] F1: 0.4359 | Acc: 0.5349 | LR: 9.76e-04
#
# === Epoch 12/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.272e-01 | Max: 6.989e+00
# [Loss] KL: 411869.031 | class: 4.131 | overall loss: 297953.621
#
# === Epoch 14/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.577e-01 | Max: 7.675e+00
# [Loss] KL: 411603.281 | class: 2.831 | overall loss: 294016.404
# [Eval] F1: 0.5784 | Acc: 0.7093 | LR: 9.46e-04
#
# === Epoch 16/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.784e-01 | Max: 8.135e+00
# [Loss] KL: 411336.375 | class: 2.997 | overall loss: 289541.901
#
# === Epoch 18/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.897e-01 | Max: 8.373e+00
# [Loss] KL: 411070.469 | class: 2.196 | overall loss: 284661.366
#
# === Epoch 20/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.056e-01 | Max: 8.777e+00
# [Loss] KL: 410805.875 | class: 2.649 | overall loss: 279180.998
# [Eval] F1: 0.6062 | Acc: 0.7442 | LR: 9.05e-04
#
# === Epoch 22/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.150e-01 | Max: 8.953e+00
# [Loss] KL: 410544.062 | class: 2.116 | overall loss: 273361.967
#
# === Epoch 24/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.021e-01 | Max: 8.743e+00
# [Loss] KL: 410285.500 | class: 2.104 | overall loss: 267108.030
# [Eval] F1: 0.6122 | Acc: 0.7674 | LR: 8.54e-04
#
# === Epoch 26/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.178e-01 | Max: 8.999e+00
# [Loss] KL: 410031.469 | class: 2.393 | overall loss: 260318.094
#
# === Epoch 28/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.393e-01 | Max: 9.520e+00
# [Loss] KL: 409782.031 | class: 1.603 | overall loss: 253060.004
#
# === Epoch 30/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.535e-01 | Max: 9.859e+00
# [Loss] KL: 409537.969 | class: 1.593 | overall loss: 245436.393
# [Eval] F1: 0.6122 | Acc: 0.7674 | LR: 7.94e-04
#
# === Epoch 32/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.285e-01 | Max: 9.321e+00
# [Loss] KL: 409300.375 | class: 2.011 | overall loss: 237697.668
#
# === Epoch 34/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.375e-01 | Max: 9.536e+00
# [Loss] KL: 409069.000 | class: 1.411 | overall loss: 229425.348
# [Eval] F1: 0.6530 | Acc: 0.7907 | LR: 7.27e-04
#
# === Epoch 36/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.526e-01 | Max: 9.875e+00
# [Loss] KL: 408844.281 | class: 1.210 | overall loss: 220859.780
#
# === Epoch 38/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.606e-01 | Max: 1.005e+01
# [Loss] KL: 408626.969 | class: 1.172 | overall loss: 212072.794
#
# === Epoch 40/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.448e-01 | Max: 9.693e+00
# [Loss] KL: 408418.250 | class: 1.215 | overall loss: 203193.507
# [Eval] F1: 0.6530 | Acc: 0.7907 | LR: 6.55e-04
#
# === Epoch 42/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.599e-01 | Max: 1.006e+01
# [Loss] KL: 408218.500 | class: 1.195 | overall loss: 193933.670
#
# === Epoch 44/100 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.362e-01 | Max: 9.556e+00
# [Loss] KL: 408028.344 | class: 1.285 | overall loss: 184703.493
# [Eval] F1: 0.6530 | Acc: 0.7907 | LR: 5.78e-04
#
# === Epoch 46/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 5.576e-01 | Max: 1.004e+01
# [Loss] KL: 407847.938 | class: 1.065 | overall loss: 175179.294
#
# === Epoch 48/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 5.201e-01 | Max: 9.250e+00
# [Loss] KL: 407677.906 | class: 1.021 | overall loss: 165801.247
#
# === Epoch 50/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 5.193e-01 | Max: 9.280e+00
# [Loss] KL: 407519.031 | class: 0.941 | overall loss: 156235.884
# [Eval] F1: 0.7121 | Acc: 0.8140 | LR: 5.00e-04
#
# === Epoch 52/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 4.929e-01 | Max: 8.762e+00
# [Loss] KL: 407371.031 | class: 1.368 | overall loss: 146729.028
#
# === Epoch 54/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 4.724e-01 | Max: 8.426e+00
# [Loss] KL: 407234.375 | class: 1.211 | overall loss: 137226.502
# [Eval] F1: 0.7121 | Acc: 0.8140 | LR: 4.22e-04
#
# === Epoch 56/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 4.514e-01 | Max: 8.040e+00
# [Loss] KL: 407109.844 | class: 0.610 | overall loss: 127796.548
#
# === Epoch 58/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 4.111e-01 | Max: 7.179e+00
# [Loss] KL: 406997.500 | class: 1.048 | overall loss: 118514.506
#
# === Epoch 60/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 3.853e-01 | Max: 6.728e+00
# [Loss] KL: 406897.094 | class: 0.712 | overall loss: 109318.787
# [Eval] F1: 0.7189 | Acc: 0.8256 | LR: 3.45e-04
#
# === Epoch 62/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 3.597e-01 | Max: 6.377e+00
# [Loss] KL: 406808.406 | class: 1.005 | overall loss: 100265.038
#
# === Epoch 64/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 3.340e-01 | Max: 5.770e+00
# [Loss] KL: 406730.531 | class: 0.900 | overall loss: 91445.668
# [Eval] F1: 0.6968 | Acc: 0.8256 | LR: 2.73e-04
#
# === Epoch 66/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 3.052e-01 | Max: 5.239e+00
# [Loss] KL: 406663.250 | class: 0.705 | overall loss: 82851.518
#
# === Epoch 68/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 2.782e-01 | Max: 4.779e+00
# [Loss] KL: 406605.688 | class: 1.058 | overall loss: 74519.408
#
# === Epoch 70/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 2.492e-01 | Max: 4.302e+00
# [Loss] KL: 406557.188 | class: 0.821 | overall loss: 66490.473
# [Eval] F1: 0.6873 | Acc: 0.8140 | LR: 2.06e-04
#
# === Epoch 72/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 2.298e-01 | Max: 3.731e+00
# [Loss] KL: 406516.781 | class: 0.792 | overall loss: 58800.647
#
# === Epoch 74/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.982e-01 | Max: 3.291e+00
# [Loss] KL: 406483.719 | class: 0.791 | overall loss: 51464.722
# [Eval] F1: 0.6873 | Acc: 0.8140 | LR: 1.46e-04
#
# === Epoch 76/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.760e-01 | Max: 2.856e+00
# [Loss] KL: 406457.094 | class: 0.931 | overall loss: 44522.646
#
# === Epoch 78/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.564e-01 | Max: 2.426e+00
# [Loss] KL: 406436.062 | class: 0.997 | overall loss: 37999.700
#
# === Epoch 80/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.337e-01 | Max: 2.037e+00
# [Loss] KL: 406419.938 | class: 0.920 | overall loss: 31920.896
# [Eval] F1: 0.6968 | Acc: 0.8256 | LR: 9.55e-05
#
# === Epoch 82/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.102e-01 | Max: 1.710e+00
# [Loss] KL: 406407.781 | class: 0.703 | overall loss: 26310.819
#
# === Epoch 84/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 9.761e-02 | Max: 1.365e+00
# [Loss] KL: 406398.906 | class: 0.870 | overall loss: 21196.562
# [Eval] F1: 0.6968 | Acc: 0.8256 | LR: 5.45e-05
#
# === Epoch 86/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 8.027e-02 | Max: 1.073e+00
# [Loss] KL: 406392.656 | class: 1.051 | overall loss: 16594.633
#
# === Epoch 88/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 7.840e-02 | Max: 7.923e-01
# [Loss] KL: 406388.531 | class: 1.020 | overall loss: 12526.985
#
# === Epoch 90/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 5.636e-02 | Max: 5.729e-01
# [Loss] KL: 406385.906 | class: 0.903 | overall loss: 9006.217
# [Eval] F1: 0.7050 | Acc: 0.8256 | LR: 2.45e-05
#
# === Epoch 92/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 4.458e-02 | Max: 3.940e-01
# [Loss] KL: 406384.312 | class: 0.762 | overall loss: 6049.815
#
# === Epoch 94/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 3.602e-02 | Max: 2.349e-01
# [Loss] KL: 406383.469 | class: 0.976 | overall loss: 3670.774
# [Eval] F1: 0.6968 | Acc: 0.8256 | LR: 6.16e-06
#
# === Epoch 96/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 3.778e-02 | Max: 2.138e-01
# [Loss] KL: 406383.094 | class: 0.843 | overall loss: 1878.405
#
# === Epoch 98/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 2.797e-02 | Max: 1.834e-01
# [Loss] KL: 406382.969 | class: 0.816 | overall loss: 677.892
#
# === Epoch 100/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 2.796e-02 | Max: 1.934e-01
# [Loss] KL: 406382.906 | class: 0.657 | overall loss: 76.875
# [Eval] F1: 0.7144 | Acc: 0.8372 | LR: 0.00e+00
# Current F1: 0.6900 | Best F1: 0.7003
#
# trial 5/30
# Parameter Combination: {'meta_lr': 0.0003, 'inner_lr': 0.1, 'num_inner_steps': 7, 'kl_weight': 0.001, 'dropout_rate': 0.2, 'num_epochs': 100, 'eval_samples': 60}
# Network structure: [512, 256, 128]
#
# === Epoch 2/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.114e-01 | Max: 1.080e+00
# [Loss] KL: 1574337.875 | class: 2.013 | overall loss: 110153.558
#
# === Epoch 4/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.109e-01 | Max: 1.191e+00
# [Loss] KL: 1574025.875 | class: 1.552 | overall loss: 109904.159
# [Eval] F1: 0.5568 | Acc: 0.7907 | LR: 2.98e-04
#
# === Epoch 6/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.297e-02 | Max: 7.292e-01
# [Loss] KL: 1573719.375 | class: 1.669 | overall loss: 109471.839
#
# === Epoch 8/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.923e-02 | Max: 6.936e-01
# [Loss] KL: 1573430.125 | class: 2.896 | overall loss: 108805.894
#
# === Epoch 10/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.544e-02 | Max: 8.310e-01
# [Loss] KL: 1573148.875 | class: 3.043 | overall loss: 107913.336
# [Eval] F1: 0.5250 | Acc: 0.7674 | LR: 2.93e-04
#
# === Epoch 12/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.481e-02 | Max: 8.461e-01
# [Loss] KL: 1572869.625 | class: 2.105 | overall loss: 106826.063
#
# === Epoch 14/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.906e-02 | Max: 9.480e-01
# [Loss] KL: 1572588.125 | class: 2.644 | overall loss: 105527.617
# [Eval] F1: 0.6274 | Acc: 0.7907 | LR: 2.84e-04
#
# === Epoch 16/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.814e-02 | Max: 9.861e-01
# [Loss] KL: 1572303.875 | class: 3.013 | overall loss: 104035.701
#
# === Epoch 18/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.675e-02 | Max: 1.154e+00
# [Loss] KL: 1572020.500 | class: 3.234 | overall loss: 102342.709
#
# === Epoch 20/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.749e-02 | Max: 1.183e+00
# [Loss] KL: 1571733.125 | class: 2.078 | overall loss: 100469.533
# [Eval] F1: 0.6693 | Acc: 0.7907 | LR: 2.71e-04
#
# === Epoch 22/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.824e-02 | Max: 1.203e+00
# [Loss] KL: 1571444.875 | class: 3.194 | overall loss: 98419.027
#
# === Epoch 24/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.056e-01 | Max: 1.369e+00
# [Loss] KL: 1571157.250 | class: 2.103 | overall loss: 96192.094
# [Eval] F1: 0.6740 | Acc: 0.7907 | LR: 2.56e-04
#
# === Epoch 26/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.140e-02 | Max: 1.082e+00
# [Loss] KL: 1570875.250 | class: 2.342 | overall loss: 93827.249
#
# === Epoch 28/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.322e-02 | Max: 1.091e+00
# [Loss] KL: 1570598.375 | class: 2.815 | overall loss: 91292.846
#
# === Epoch 30/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.021e-01 | Max: 1.304e+00
# [Loss] KL: 1570327.875 | class: 2.700 | overall loss: 88607.616
# [Eval] F1: 0.6740 | Acc: 0.7907 | LR: 2.38e-04
#
# === Epoch 32/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.814e-02 | Max: 1.253e+00
# [Loss] KL: 1570063.125 | class: 2.166 | overall loss: 85802.411
#
# === Epoch 34/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.453e-02 | Max: 1.109e+00
# [Loss] KL: 1569805.875 | class: 2.204 | overall loss: 82881.501
# [Eval] F1: 0.6911 | Acc: 0.8140 | LR: 2.18e-04
#
# === Epoch 36/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 1.052e-01 | Max: 1.406e+00
# [Loss] KL: 1569555.500 | class: 1.640 | overall loss: 79831.211
#
# === Epoch 38/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.376e-02 | Max: 1.231e+00
# [Loss] KL: 1569316.250 | class: 1.960 | overall loss: 76705.790
#
# === Epoch 40/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 9.270e-02 | Max: 1.182e+00
# [Loss] KL: 1569088.125 | class: 1.713 | overall loss: 73489.342
# [Eval] F1: 0.7023 | Acc: 0.8256 | LR: 1.96e-04
#
# === Epoch 42/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.837e-02 | Max: 1.122e+00
# [Loss] KL: 1568872.750 | class: 1.496 | overall loss: 70201.789
#
# === Epoch 44/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.750e-02 | Max: 1.112e+00
# [Loss] KL: 1568669.000 | class: 1.653 | overall loss: 66853.021
# [Eval] F1: 0.6794 | Acc: 0.8256 | LR: 1.73e-04
#
# === Epoch 46/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.687e-02 | Max: 1.068e+00
# [Loss] KL: 1568476.250 | class: 2.139 | overall loss: 63459.823
#
# === Epoch 48/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.478e-02 | Max: 1.035e+00
# [Loss] KL: 1568297.625 | class: 1.537 | overall loss: 60033.614
#
# === Epoch 50/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.457e-02 | Max: 8.098e-01
# [Loss] KL: 1568133.750 | class: 1.571 | overall loss: 56595.456
# [Eval] F1: 0.6727 | Acc: 0.8140 | LR: 1.50e-04
#
# === Epoch 52/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.588e-02 | Max: 8.395e-01
# [Loss] KL: 1567985.125 | class: 1.857 | overall loss: 53140.390
#
# === Epoch 54/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.060e-02 | Max: 7.253e-01
# [Loss] KL: 1567850.500 | class: 2.442 | overall loss: 49700.105
# [Eval] F1: 0.6893 | Acc: 0.8256 | LR: 1.27e-04
#
# === Epoch 56/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.045e-02 | Max: 7.726e-01
# [Loss] KL: 1567729.750 | class: 1.359 | overall loss: 46275.161
#
# === Epoch 58/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.875e-02 | Max: 7.313e-01
# [Loss] KL: 1567621.625 | class: 1.325 | overall loss: 42887.546
#
# === Epoch 60/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.317e-02 | Max: 6.810e-01
# [Loss] KL: 1567526.125 | class: 1.537 | overall loss: 39548.199
# [Eval] F1: 0.6893 | Acc: 0.8256 | LR: 1.04e-04
#
# === Epoch 62/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.143e-02 | Max: 6.924e-01
# [Loss] KL: 1567442.250 | class: 1.649 | overall loss: 36267.921
#
# === Epoch 64/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.853e-02 | Max: 5.764e-01
# [Loss] KL: 1567368.125 | class: 0.984 | overall loss: 33065.603
# [Eval] F1: 0.6893 | Acc: 0.8256 | LR: 8.19e-05
#
# === Epoch 66/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.520e-02 | Max: 5.432e-01
# [Loss] KL: 1567303.375 | class: 1.468 | overall loss: 29946.846
#
# === Epoch 68/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.844e-02 | Max: 5.409e-01
# [Loss] KL: 1567247.750 | class: 0.853 | overall loss: 26925.836
#
# === Epoch 70/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.701e-02 | Max: 4.465e-01
# [Loss] KL: 1567200.375 | class: 1.856 | overall loss: 24018.091
# [Eval] F1: 0.7082 | Acc: 0.8372 | LR: 6.18e-05
#
# === Epoch 72/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.665e-02 | Max: 3.977e-01
# [Loss] KL: 1567161.375 | class: 1.266 | overall loss: 21230.485
#
# === Epoch 74/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 4.015e-02 | Max: 3.621e-01
# [Loss] KL: 1567129.250 | class: 1.391 | overall loss: 18575.338
# [Eval] F1: 0.7082 | Acc: 0.8372 | LR: 4.39e-05
#
# === Epoch 76/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 3.988e-02 | Max: 2.783e-01
# [Loss] KL: 1567103.625 | class: 0.947 | overall loss: 16065.372
#
# === Epoch 78/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 3.620e-02 | Max: 2.584e-01
# [Loss] KL: 1567083.500 | class: 1.102 | overall loss: 13707.295
#
# === Epoch 80/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 3.787e-02 | Max: 1.976e-01
# [Loss] KL: 1567067.875 | class: 1.066 | overall loss: 11512.073
# [Eval] F1: 0.7082 | Acc: 0.8372 | LR: 2.86e-05
#
# === Epoch 82/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 3.532e-02 | Max: 1.784e-01
# [Loss] KL: 1567056.375 | class: 1.587 | overall loss: 9486.017
#
# === Epoch 84/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 3.201e-02 | Max: 1.741e-01
# [Loss] KL: 1567047.875 | class: 1.352 | overall loss: 7639.639
# [Eval] F1: 0.6981 | Acc: 0.8256 | LR: 1.63e-05
#
# === Epoch 86/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 3.129e-02 | Max: 1.810e-01
# [Loss] KL: 1567041.875 | class: 1.806 | overall loss: 5981.141
#
# === Epoch 88/100 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 2.626e-02 | Max: 1.387e-01
# ...
# [Eval] F1: 0.7149 | Acc: 0.8488 | LR: 3.45e-04
#
# === Epoch 62/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 2.182e-01 | Max: 3.533e+00
# [Loss] KL: 1548829.250 | class: 0.618 | overall loss: 107378.380
#
# === Epoch 64/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 2.022e-01 | Max: 3.238e+00
# [Loss] KL: 1548528.375 | class: 0.565 | overall loss: 97886.801
# [Eval] F1: 0.7261 | Acc: 0.8605 | LR: 2.73e-04
#
# === Epoch 66/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.869e-01 | Max: 2.892e+00
# [Loss] KL: 1548266.500 | class: 0.661 | overall loss: 88655.388
#
# === Epoch 68/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.655e-01 | Max: 2.634e+00
# [Loss] KL: 1548042.000 | class: 0.605 | overall loss: 79713.408
#
# === Epoch 70/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.539e-01 | Max: 2.338e+00
# [Loss] KL: 1547851.875 | class: 0.690 | overall loss: 71101.501
# [Eval] F1: 0.7261 | Acc: 0.8605 | LR: 2.06e-04
#
# === Epoch 72/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.345e-01 | Max: 2.064e+00
# [Loss] KL: 1547693.625 | class: 0.518 | overall loss: 62850.093
#
# === Epoch 74/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.214e-01 | Max: 1.794e+00
# [Loss] KL: 1547563.750 | class: 0.644 | overall loss: 54992.847
# [Eval] F1: 0.7149 | Acc: 0.8488 | LR: 1.46e-04
#
# === Epoch 76/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 1.118e-01 | Max: 1.576e+00
# [Loss] KL: 1547459.250 | class: 0.951 | overall loss: 47558.456
#
# === Epoch 78/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 9.102e-02 | Max: 1.345e+00
# [Loss] KL: 1547376.375 | class: 0.601 | overall loss: 40577.131
#
# === Epoch 80/100 ===
# [Param] Weighted variance range: 0.019~0.051
# [Grad] mean value: 8.143e-02 | Max: 1.117e+00
# [Loss] KL: 1547312.625 | class: 0.690 | overall loss: 34076.846
# ! Early stop is triggered at epoch 80，Best F1: 0.7378
# Current F1: 0.7149 | Best F1: 0.7431
#
# Conduct the final training using the best parameters...
#
# === Epoch 2/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.955e-02 | Max: 6.850e-01
# [Loss] KL: 1574393.500 | class: 1.781 | overall loss: 66117.824
#
# === Epoch 4/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 8.506e-02 | Max: 7.221e-01
# [Loss] KL: 1574082.750 | class: 2.109 | overall loss: 66042.894
# [Eval] F1: 0.4625 | Acc: 0.6047 | LR: 2.99e-04
#
# === Epoch 6/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.363e-02 | Max: 3.493e-01
# [Loss] KL: 1573778.250 | class: 3.021 | overall loss: 65930.438
#
# === Epoch 8/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.272e-02 | Max: 3.889e-01
# [Loss] KL: 1573492.750 | class: 2.924 | overall loss: 65745.515
#
# === Epoch 10/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.421e-02 | Max: 4.530e-01
# [Loss] KL: 1573211.875 | class: 2.497 | overall loss: 65494.127
# [Eval] F1: 0.5374 | Acc: 0.7209 | LR: 2.97e-04
#
# === Epoch 12/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.492e-02 | Max: 4.806e-01
# [Loss] KL: 1572931.250 | class: 2.520 | overall loss: 65194.044
#
# === Epoch 14/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.041e-02 | Max: 6.706e-01
# [Loss] KL: 1572646.625 | class: 3.202 | overall loss: 64828.022
# [Eval] F1: 0.6151 | Acc: 0.7791 | LR: 2.93e-04
#
# === Epoch 16/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.809e-02 | Max: 6.207e-01
# [Loss] KL: 1572356.625 | class: 2.542 | overall loss: 64419.100
#
# === Epoch 18/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.149e-02 | Max: 6.765e-01
# [Loss] KL: 1572062.250 | class: 2.472 | overall loss: 63950.326
#
# === Epoch 20/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.446e-02 | Max: 7.783e-01
# [Loss] KL: 1571762.125 | class: 2.448 | overall loss: 63423.862
# [Eval] F1: 0.6274 | Acc: 0.7907 | LR: 2.87e-04
#
# === Epoch 22/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.410e-02 | Max: 7.543e-01
# [Loss] KL: 1571456.250 | class: 2.191 | overall loss: 62850.713
#
# === Epoch 24/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.680e-02 | Max: 8.317e-01
# [Loss] KL: 1571147.625 | class: 2.472 | overall loss: 62221.254
# [Eval] F1: 0.6579 | Acc: 0.8023 | LR: 2.80e-04
#
# === Epoch 26/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.771e-02 | Max: 8.680e-01
# [Loss] KL: 1570833.750 | class: 2.085 | overall loss: 61540.794
#
# === Epoch 28/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.839e-02 | Max: 9.189e-01
# [Loss] KL: 1570521.375 | class: 2.063 | overall loss: 60812.127
#
# === Epoch 30/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.881e-02 | Max: 9.183e-01
# [Loss] KL: 1570207.250 | class: 1.515 | overall loss: 60035.065
# [Eval] F1: 0.6475 | Acc: 0.7907 | LR: 2.71e-04
#
# === Epoch 32/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.375e-02 | Max: 7.745e-01
# [Loss] KL: 1569896.750 | class: 1.735 | overall loss: 59217.603
#
# === Epoch 34/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.914e-02 | Max: 9.932e-01
# [Loss] KL: 1569587.375 | class: 1.615 | overall loss: 58340.384
# [Eval] F1: 0.6475 | Acc: 0.7907 | LR: 2.61e-04
#
# === Epoch 36/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.488e-02 | Max: 8.065e-01
# [Loss] KL: 1569281.125 | class: 1.224 | overall loss: 57433.647
#
# === Epoch 38/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.702e-02 | Max: 8.592e-01
# [Loss] KL: 1568984.250 | class: 1.340 | overall loss: 56476.636
#
# === Epoch 40/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.543e-02 | Max: 8.577e-01
# [Loss] KL: 1568692.250 | class: 0.899 | overall loss: 55480.442
# [Eval] F1: 0.6381 | Acc: 0.7791 | LR: 2.50e-04
#
# === Epoch 42/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.359e-02 | Max: 8.246e-01
# [Loss] KL: 1568401.875 | class: 1.645 | overall loss: 54445.386
#
# === Epoch 44/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.089e-02 | Max: 7.475e-01
# [Loss] KL: 1568118.375 | class: 1.961 | overall loss: 53375.369
# [Eval] F1: 0.6530 | Acc: 0.7907 | LR: 2.38e-04
#
# === Epoch 46/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.304e-02 | Max: 8.182e-01
# [Loss] KL: 1567842.000 | class: 1.284 | overall loss: 52265.921
#
# === Epoch 48/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.270e-02 | Max: 8.449e-01
# [Loss] KL: 1567576.000 | class: 1.209 | overall loss: 51123.838
#
# === Epoch 50/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.215e-02 | Max: 8.482e-01
# [Loss] KL: 1567315.750 | class: 1.679 | overall loss: 49951.064
# [Eval] F1: 0.6698 | Acc: 0.8023 | LR: 2.25e-04
#
# === Epoch 52/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.080e-02 | Max: 8.198e-01
# [Loss] KL: 1567061.125 | class: 1.764 | overall loss: 48750.347
#
# === Epoch 54/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.223e-02 | Max: 8.149e-01
# [Loss] KL: 1566815.625 | class: 1.683 | overall loss: 47521.168
# [Eval] F1: 0.6791 | Acc: 0.8140 | LR: 2.11e-04
#
# === Epoch 56/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.927e-02 | Max: 7.998e-01
# [Loss] KL: 1566577.125 | class: 1.401 | overall loss: 46268.574
#
# === Epoch 58/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 7.066e-02 | Max: 8.756e-01
# [Loss] KL: 1566344.375 | class: 1.676 | overall loss: 44988.609
#
# === Epoch 60/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.866e-02 | Max: 7.895e-01
# [Loss] KL: 1566120.125 | class: 1.465 | overall loss: 43694.065
# [Eval] F1: 0.6791 | Acc: 0.8140 | LR: 1.96e-04
#
# === Epoch 62/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.864e-02 | Max: 7.314e-01
# [Loss] KL: 1565907.000 | class: 1.105 | overall loss: 42379.433
#
# === Epoch 64/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.450e-02 | Max: 7.400e-01
# [Loss] KL: 1565702.375 | class: 1.318 | overall loss: 41047.427
# [Eval] F1: 0.6791 | Acc: 0.8140 | LR: 1.81e-04
#
# === Epoch 66/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.627e-02 | Max: 7.338e-01
# [Loss] KL: 1565507.375 | class: 1.307 | overall loss: 39701.567
#
# === Epoch 68/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.201e-02 | Max: 7.301e-01
# [Loss] KL: 1565321.625 | class: 1.286 | overall loss: 38344.557
#
# === Epoch 70/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.212e-02 | Max: 6.584e-01
# [Loss] KL: 1565146.375 | class: 1.118 | overall loss: 36980.805
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 1.66e-04
#
# === Epoch 72/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 6.067e-02 | Max: 6.825e-01
# [Loss] KL: 1564979.250 | class: 1.542 | overall loss: 35606.542
#
# === Epoch 74/150 ===
# [Param] Weighted variance range: 0.018~0.049
# [Grad] mean value: 5.749e-02 | Max: 6.036e-01
# [Loss] KL: 1564821.875 | class: 1.944 | overall loss: 34232.671
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 1.50e-04
#
# === Epoch 76/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.746e-02 | Max: 5.671e-01
# [Loss] KL: 1564675.625 | class: 1.635 | overall loss: 32853.798
#
# === Epoch 78/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.562e-02 | Max: 5.751e-01
# [Loss] KL: 1564538.375 | class: 1.227 | overall loss: 31474.455
#
# === Epoch 80/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.420e-02 | Max: 5.767e-01
# [Loss] KL: 1564410.250 | class: 1.431 | overall loss: 30098.603
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 1.34e-04
#
# === Epoch 82/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.348e-02 | Max: 5.899e-01
# [Loss] KL: 1564289.625 | class: 1.170 | overall loss: 28727.432
#
# === Epoch 84/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.825e-02 | Max: 5.614e-01
# [Loss] KL: 1564177.875 | class: 1.232 | overall loss: 27364.441
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 1.19e-04
#
# === Epoch 86/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 5.191e-02 | Max: 4.849e-01
# [Loss] KL: 1564074.125 | class: 1.676 | overall loss: 26013.449
#
# === Epoch 88/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.897e-02 | Max: 4.610e-01
# [Loss] KL: 1563979.375 | class: 1.061 | overall loss: 24673.577
#
# === Epoch 90/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.814e-02 | Max: 4.342e-01
# [Loss] KL: 1563892.750 | class: 1.590 | overall loss: 23347.037
# [Eval] F1: 0.7312 | Acc: 0.8372 | LR: 1.04e-04
#
# === Epoch 92/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.502e-02 | Max: 4.305e-01
# [Loss] KL: 1563814.000 | class: 0.991 | overall loss: 22037.599
#
# === Epoch 94/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.373e-02 | Max: 3.910e-01
# [Loss] KL: 1563742.250 | class: 1.010 | overall loss: 20748.142
# [Eval] F1: 0.6981 | Acc: 0.8256 | LR: 8.90e-05
#
# === Epoch 96/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.712e-02 | Max: 4.054e-01
# [Loss] KL: 1563677.625 | class: 1.255 | overall loss: 19478.483
#
# === Epoch 98/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.328e-02 | Max: 3.587e-01
# [Loss] KL: 1563619.125 | class: 1.216 | overall loss: 18234.742
#
# === Epoch 100/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.885e-02 | Max: 3.306e-01
# [Loss] KL: 1563567.125 | class: 1.588 | overall loss: 17015.756
# [Eval] F1: 0.6981 | Acc: 0.8256 | LR: 7.50e-05
#
# === Epoch 102/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 4.186e-02 | Max: 2.827e-01
# [Loss] KL: 1563520.625 | class: 0.707 | overall loss: 15825.847
#
# === Epoch 104/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.754e-02 | Max: 2.850e-01
# [Loss] KL: 1563480.125 | class: 0.874 | overall loss: 14663.358
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 6.18e-05
#
# === Epoch 106/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.386e-02 | Max: 2.687e-01
# [Loss] KL: 1563444.250 | class: 0.804 | overall loss: 13533.513
#
# === Epoch 108/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.184e-02 | Max: 2.525e-01
# [Loss] KL: 1563412.875 | class: 1.219 | overall loss: 12438.390
#
# === Epoch 110/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.354e-02 | Max: 2.225e-01
# [Loss] KL: 1563385.625 | class: 1.183 | overall loss: 11379.036
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 4.96e-05
#
# === Epoch 112/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.780e-02 | Max: 1.873e-01
# [Loss] KL: 1563362.500 | class: 1.016 | overall loss: 10358.964
#
# === Epoch 114/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.271e-02 | Max: 1.807e-01
# [Loss] KL: 1563342.875 | class: 1.450 | overall loss: 9374.940
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 3.85e-05
#
# === Epoch 116/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 3.282e-02 | Max: 1.647e-01
# [Loss] KL: 1563326.500 | class: 1.560 | overall loss: 8433.305
#
# === Epoch 118/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.622e-02 | Max: 1.517e-01
# [Loss] KL: 1563312.750 | class: 1.288 | overall loss: 7534.467
#
# === Epoch 120/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.535e-02 | Max: 1.352e-01
# [Loss] KL: 1563301.375 | class: 1.226 | overall loss: 6680.160
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 2.86e-05
#
# === Epoch 122/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.716e-02 | Max: 1.433e-01
# [Loss] KL: 1563292.250 | class: 0.867 | overall loss: 5872.597
#
# === Epoch 124/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.547e-02 | Max: 1.398e-01
# [Loss] KL: 1563284.875 | class: 1.303 | overall loss: 5111.464
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 2.01e-05
#
# === Epoch 126/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.556e-02 | Max: 1.450e-01
# [Loss] KL: 1563278.875 | class: 1.632 | overall loss: 4399.346
#
# === Epoch 128/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.265e-02 | Max: 1.311e-01
# [Loss] KL: 1563274.500 | class: 1.000 | overall loss: 3737.222
#
# === Epoch 130/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.162e-02 | Max: 1.233e-01
# [Loss] KL: 1563271.000 | class: 1.421 | overall loss: 3125.730
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 1.30e-05
#
# === Epoch 132/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.044e-02 | Max: 1.168e-01
# [Loss] KL: 1563268.375 | class: 1.127 | overall loss: 2565.927
#
# === Epoch 134/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.578e-02 | Max: 1.652e-01
# [Loss] KL: 1563266.625 | class: 0.928 | overall loss: 2060.628
# [Eval] F1: 0.7195 | Acc: 0.8488 | LR: 7.34e-06
#
# === Epoch 136/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.096e-02 | Max: 1.307e-01
# [Loss] KL: 1563265.375 | class: 1.449 | overall loss: 1607.609
#
# === Epoch 138/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.152e-02 | Max: 1.414e-01
# [Loss] KL: 1563264.500 | class: 1.256 | overall loss: 1210.920
#
# === Epoch 140/150 ===
# [Param] Weighted variance range: 0.019~0.050
# [Grad] mean value: 2.134e-02 | Max: 1.382e-01
# [Loss] KL: 1563264.000 | class: 1.229 | overall loss: 868.628
# ! Early stop is triggered at epoch 140，Best F1: 0.7312
#
# Final Performance:
# Accuracy: 0.8488
# F1: 0.7195
# confusion_matrix:
#  [[34  1  1  1]
#  [ 2  2  1  1]
#  [ 3  2 33  0]
#  [ 1  0  0  4]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
conf_matrix = final_metrics['confusion_matrix']

plt.figure(figsize=(5, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('confusion_matrix.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 6))
window_size = 5
smoothed_losses = np.convolve(final_losses, np.ones(window_size) / window_size, mode='valid')
plt.plot(final_losses, alpha=0.3, label='Raw Loss', color='darkred')
plt.plot(range(window_size - 1, len(final_losses)), smoothed_losses,
             linewidth=2, label=f'Smoothed (window={window_size})', color='darkblue')

plt.title('Training Loss Curve\n(Final Model)', fontsize=14, pad=20)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Normalized Loss', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

    # Mark the best epoch
best_epoch = np.argmin(smoothed_losses)
plt.scatter(best_epoch + window_size - 1, smoothed_losses[best_epoch],
                color='red', zorder=5, label=f'Best Epoch: {best_epoch + window_size}')
plt.annotate(f'Min Loss: {smoothed_losses[best_epoch]:.2f}',
                 (best_epoch + window_size - 1, smoothed_losses[best_epoch]),
                 textcoords="offset points", xytext=(0, 10), ha='center')

plt.tight_layout()
plt.savefig('training_loss_curve.png', dpi=300, bbox_inches='tight')
plt.show()
